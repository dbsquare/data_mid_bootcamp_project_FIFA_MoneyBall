# %% [markdown]
# ## Project FIFA

# %% [markdown]
# #### Importing the libraries and reading the data

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder

# %%
df_initial = pd.read_csv('fifa21_male2.csv', index_col=['ID'])

# %% [markdown]
# #### Exploring the dataset

# %%
df_initial.head()
# Out:
#            Name  Age  OVA            Nationality           Club  BOV   BP  \
# ID
# 2   G. Pasquale   33   69                  Italy        Udinese   71  LWB
# 16  Luis García   37   71                  Spain      KAS Eupen   70   CM
# 27      J. Cole   33   71                England  Coventry City   71  CAM
# 36     D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70   ST
# 41      Iniesta   36   81                  Spain    Vissel Kobe   82  CAM
#
#         Position                                       Player Photo  \
# ID
# 2             LM  https://cdn.sofifa.com/players/000/002/16_120.png
# 16    CM CAM CDM  https://cdn.sofifa.com/players/000/016/19_120.png
# 27  CAM RM RW LM  https://cdn.sofifa.com/players/000/027/16_120.png
# 36           NaN  https://cdn.sofifa.com/players/000/036/09_120.png
# 41        CM CAM  https://cdn.sofifa.com/players/000/041/20_120.png
#
#                                            Club Logo  \
# ID
# 2       https://cdn.sofifa.com/teams/55/light_60.png
# 16    https://cdn.sofifa.com/teams/2013/light_60.png
# 27    https://cdn.sofifa.com/teams/1800/light_60.png
# 36     https://cdn.sofifa.com/teams/106/light_60.png
# 41  https://cdn.sofifa.com/teams/101146/light_60.png
#
#                                  Flag Photo  POT            Team & Contract  \
# ID
# 2       https://cdn.sofifa.com/flags/it.png   69        Udinese 2008 ~ 2016
# 16      https://cdn.sofifa.com/flags/es.png   71      KAS Eupen 2014 ~ 2019
# 27  https://cdn.sofifa.com/flags/gb-eng.png   71  Coventry City 2016 ~ 2020
# 36      https://cdn.sofifa.com/flags/tt.png   82            Sunderland 2009
# 41      https://cdn.sofifa.com/flags/es.png   81    Vissel Kobe 2018 ~ 2021
#
#    Height  Weight   foot  Growth        Joined Loan Date End  Value  Wage  \
# ID
# 2    6'0"  181lbs   Left       0   Jul 1, 2008           NaN  €625K   €7K
# 16  5'10"  143lbs  Right       0  Jul 19, 2014           NaN  €600K   €7K
# 27   5'9"  161lbs  Right       0   Jan 7, 2016           NaN  €1.1M  €15K
# 36  5'11"  165lbs  Right      14           NaN           NaN     €0    €0
# 41   5'7"  150lbs  Right       0  Jul 16, 2018           NaN  €5.5M  €12K
#
#    Release Clause     Contract  Attacking  Crossing  Finishing  \
# ID
# 2              €0  2008 ~ 2016        313        75         50
# 16          €1.1M  2014 ~ 2019        337        68         64
# 27             €0  2016 ~ 2020        337        80         64
# 36             €0         2009        264        54         70
# 41          €7.2M  2018 ~ 2021        367        75         69
#
#     Heading Accuracy  Short Passing  Volleys  Skill  Dribbling  Curve  \
# ID
# 2                 59             71     58.0    338         73   65.0
# 16                61             76     68.0    369         69   79.0
# 27                41             77     75.0    387         79   84.0
# 36                60             80      NaN    255         68    NaN
# 41                54             90     79.0    408         85   80.0
#
#     FK Accuracy  Long Passing  Ball Control  Movement  Acceleration  \
# ID
# 2            60            69            71       347            68
# 16           79            71            71       305            56
# 27           77            69            78       295            48
# 36           46            64            77       176            59
# 41           70            83            90       346            61
#
#     Sprint Speed  Agility  Reactions  Balance  Power  Shot Power  Jumping  \
# ID
# 2             74     68.0         69     68.0    347          74     68.0
# 16            50     62.0         65     72.0    324          75     54.0
# 27            42     71.0         59     75.0    284          72     58.0
# 36            62      NaN         55      NaN    239          63      NaN
# 41            56     79.0         75     75.0    297          67     40.0
#
#     Stamina  Strength  Long Shots  Mentality  Aggression  Interceptions  \
# ID
# 2        69        68          68        320          72           69.0
# 16       64        60          71        362          71           71.0
# 27       29        56          69        317          69           39.0
# 36       51        66          59        271          59           70.0
# 41       58        62          70        370          58           70.0
#
#     Positioning  Vision  Penalties  Composure  Defending  Marking  \
# ID
# 2          63.0    66.0         50        NaN        208       70
# 16         72.0    73.0         75       79.0        153       70
# 27         69.0    74.0         66        NaN         99       35
# 36         72.0     NaN         70        NaN         75       34
# 41         78.0    93.0         71       89.0        181       68
#
#     Standing Tackle  Sliding Tackle  Goalkeeping  GK Diving  GK Handling  \
# ID
# 2                69            69.0           56         14            5
# 16               43            40.0           56          9           12
# 27               34            30.0           51          9            6
# 36               41             NaN           68          5           21
# 41               57            56.0           45          6           13
#
#     GK Kicking  GK Positioning  GK Reflexes  Total Stats  Base Stats  W/F  SM  \
# ID
# 2           15              10           12         1929         408  3 ★  2★
# 16          13              11           11         1906         385  4 ★  3★
# 27          13              16            7         1770         354  4 ★  4★
# 36          64              21           21         1348         369  3 ★  1★
# 41           6              13            7         2014         420  4 ★  4★
#
#        A/W     D/W   IR  PAC  SHO  PAS  DRI  DEF  PHY Hits    LS    ST    RS  \
# ID
# 2   Medium    High  2 ★   71   59   70   71   68   69    4  65+0  65+0  65+0
# 16  Medium  Medium  1 ★   53   69   73   69   58   63    4  67+1  67+1  67+1
# 27  Medium     Low  2 ★   45   68   76   77   36   52   11  64+0  64+0  64+0
# 36     NaN     NaN  1 ★   61   66   66   69   47   60    3  67+0  67+0  67+0
# 41    High  Medium  4 ★   58   70   85   85   63   59  149  72+3  72+3  72+3
#
#       LW    LF    CF    RF    RW    LAM    CAM    RAM    LM   LCM    CM   RCM  \
# ID
# 2   68+0  67+0  67+0  67+0  68+0   68+0   68+0   68+0  69+0  69+0  69+0  69+0
# 16  67+0  68+0  68+0  68+0  67+0   70+1   70+1   70+1  68+1  70+1  70+1  70+1
# 27  70+0  69+0  69+0  69+0  70+0   71+0   71+0   71+0  68+0  66+0  66+0  66+0
# 36  66+0  67+0  67+0  67+0  66+0   70+0   70+0   70+0  66+0  68+0  68+0  68+0
# 41  79+0  79+0  79+0  79+0  79+0  82+-1  82+-1  82+-1  79+2  81+0  81+0  81+0
#
#       RM    LWB    LDM    CDM    RDM    RWB     LB   LCB    CB   RCB     RB  \
# ID
# 2   69+0  71+-2  70+-1  70+-1  70+-1  71+-2  70+-1  69+0  69+0  69+0  70+-1
# 16  68+1   62+1   66+1   66+1   66+1   62+1   60+1  60+1  60+1  60+1   60+1
# 27  68+0   52+0   54+0   54+0   54+0   52+0   47+0  46+0  46+0  46+0   47+0
# 36  66+0   56+0   65+0   65+0   65+0   56+0   57+0  51+0  51+0  51+0   57+0
# 41  79+2   70+3   73+3   73+3   73+3   70+3   67+3  64+3  64+3  64+3   67+3
#
#       GK Gender
# ID
# 2   17+0   Male
# 16  17+1   Male
# 27  15+0   Male
# 36  22+0   Male
# 41  17+3   Male

# %%
df_initial = df_initial.drop(['Player Photo', 'Club Logo', 'Flag Photo', 'Team & Contract', 'Joined', 'Name', 'Nationality', 'Club', 'Position', 'Gender'], axis = 1)
df_initial.head()
# Out:
#     Age  OVA  BOV   BP  POT Height  Weight   foot  Growth Loan Date End  \
# ID
# 2    33   69   71  LWB   69   6'0"  181lbs   Left       0           NaN
# 16   37   71   70   CM   71  5'10"  143lbs  Right       0           NaN
# 27   33   71   71  CAM   71   5'9"  161lbs  Right       0           NaN
# 36   36   68   70   ST   82  5'11"  165lbs  Right      14           NaN
# 41   36   81   82  CAM   81   5'7"  150lbs  Right       0           NaN
#
#     Value  Wage Release Clause     Contract  Attacking  Crossing  Finishing  \
# ID
# 2   €625K   €7K             €0  2008 ~ 2016        313        75         50
# 16  €600K   €7K          €1.1M  2014 ~ 2019        337        68         64
# 27  €1.1M  €15K             €0  2016 ~ 2020        337        80         64
# 36     €0    €0             €0         2009        264        54         70
# 41  €5.5M  €12K          €7.2M  2018 ~ 2021        367        75         69
#
#     Heading Accuracy  Short Passing  Volleys  Skill  Dribbling  Curve  \
# ID
# 2                 59             71     58.0    338         73   65.0
# 16                61             76     68.0    369         69   79.0
# 27                41             77     75.0    387         79   84.0
# 36                60             80      NaN    255         68    NaN
# 41                54             90     79.0    408         85   80.0
#
#     FK Accuracy  Long Passing  Ball Control  Movement  Acceleration  \
# ID
# 2            60            69            71       347            68
# 16           79            71            71       305            56
# 27           77            69            78       295            48
# 36           46            64            77       176            59
# 41           70            83            90       346            61
#
#     Sprint Speed  Agility  Reactions  Balance  Power  Shot Power  Jumping  \
# ID
# 2             74     68.0         69     68.0    347          74     68.0
# 16            50     62.0         65     72.0    324          75     54.0
# 27            42     71.0         59     75.0    284          72     58.0
# 36            62      NaN         55      NaN    239          63      NaN
# 41            56     79.0         75     75.0    297          67     40.0
#
#     Stamina  Strength  Long Shots  Mentality  Aggression  Interceptions  \
# ID
# 2        69        68          68        320          72           69.0
# 16       64        60          71        362          71           71.0
# 27       29        56          69        317          69           39.0
# 36       51        66          59        271          59           70.0
# 41       58        62          70        370          58           70.0
#
#     Positioning  Vision  Penalties  Composure  Defending  Marking  \
# ID
# 2          63.0    66.0         50        NaN        208       70
# 16         72.0    73.0         75       79.0        153       70
# 27         69.0    74.0         66        NaN         99       35
# 36         72.0     NaN         70        NaN         75       34
# 41         78.0    93.0         71       89.0        181       68
#
#     Standing Tackle  Sliding Tackle  Goalkeeping  GK Diving  GK Handling  \
# ID
# 2                69            69.0           56         14            5
# 16               43            40.0           56          9           12
# 27               34            30.0           51          9            6
# 36               41             NaN           68          5           21
# 41               57            56.0           45          6           13
#
#     GK Kicking  GK Positioning  GK Reflexes  Total Stats  Base Stats  W/F  SM  \
# ID
# 2           15              10           12         1929         408  3 ★  2★
# 16          13              11           11         1906         385  4 ★  3★
# 27          13              16            7         1770         354  4 ★  4★
# 36          64              21           21         1348         369  3 ★  1★
# 41           6              13            7         2014         420  4 ★  4★
#
#        A/W     D/W   IR  PAC  SHO  PAS  DRI  DEF  PHY Hits    LS    ST    RS  \
# ID
# 2   Medium    High  2 ★   71   59   70   71   68   69    4  65+0  65+0  65+0
# 16  Medium  Medium  1 ★   53   69   73   69   58   63    4  67+1  67+1  67+1
# 27  Medium     Low  2 ★   45   68   76   77   36   52   11  64+0  64+0  64+0
# 36     NaN     NaN  1 ★   61   66   66   69   47   60    3  67+0  67+0  67+0
# 41    High  Medium  4 ★   58   70   85   85   63   59  149  72+3  72+3  72+3
#
#       LW    LF    CF    RF    RW    LAM    CAM    RAM    LM   LCM    CM   RCM  \
# ID
# 2   68+0  67+0  67+0  67+0  68+0   68+0   68+0   68+0  69+0  69+0  69+0  69+0
# 16  67+0  68+0  68+0  68+0  67+0   70+1   70+1   70+1  68+1  70+1  70+1  70+1
# 27  70+0  69+0  69+0  69+0  70+0   71+0   71+0   71+0  68+0  66+0  66+0  66+0
# 36  66+0  67+0  67+0  67+0  66+0   70+0   70+0   70+0  66+0  68+0  68+0  68+0
# 41  79+0  79+0  79+0  79+0  79+0  82+-1  82+-1  82+-1  79+2  81+0  81+0  81+0
#
#       RM    LWB    LDM    CDM    RDM    RWB     LB   LCB    CB   RCB     RB  \
# ID
# 2   69+0  71+-2  70+-1  70+-1  70+-1  71+-2  70+-1  69+0  69+0  69+0  70+-1
# 16  68+1   62+1   66+1   66+1   66+1   62+1   60+1  60+1  60+1  60+1   60+1
# 27  68+0   52+0   54+0   54+0   54+0   52+0   47+0  46+0  46+0  46+0   47+0
# 36  66+0   56+0   65+0   65+0   65+0   56+0   57+0  51+0  51+0  51+0   57+0
# 41  79+2   70+3   73+3   73+3   73+3   70+3   67+3  64+3  64+3  64+3   67+3
#
#       GK
# ID
# 2   17+0
# 16  17+1
# 27  15+0
# 36  22+0
# 41  17+3

# %%
df_initial.head()
# Out:
#     Age  OVA  BOV   BP  POT Height  Weight   foot  Growth Loan Date End  \
# ID
# 2    33   69   71  LWB   69   6'0"  181lbs   Left       0           NaN
# 16   37   71   70   CM   71  5'10"  143lbs  Right       0           NaN
# 27   33   71   71  CAM   71   5'9"  161lbs  Right       0           NaN
# 36   36   68   70   ST   82  5'11"  165lbs  Right      14           NaN
# 41   36   81   82  CAM   81   5'7"  150lbs  Right       0           NaN
#
#     Value  Wage Release Clause     Contract  Attacking  Crossing  Finishing  \
# ID
# 2   €625K   €7K             €0  2008 ~ 2016        313        75         50
# 16  €600K   €7K          €1.1M  2014 ~ 2019        337        68         64
# 27  €1.1M  €15K             €0  2016 ~ 2020        337        80         64
# 36     €0    €0             €0         2009        264        54         70
# 41  €5.5M  €12K          €7.2M  2018 ~ 2021        367        75         69
#
#     Heading Accuracy  Short Passing  Volleys  Skill  Dribbling  Curve  \
# ID
# 2                 59             71     58.0    338         73   65.0
# 16                61             76     68.0    369         69   79.0
# 27                41             77     75.0    387         79   84.0
# 36                60             80      NaN    255         68    NaN
# 41                54             90     79.0    408         85   80.0
#
#     FK Accuracy  Long Passing  Ball Control  Movement  Acceleration  \
# ID
# 2            60            69            71       347            68
# 16           79            71            71       305            56
# 27           77            69            78       295            48
# 36           46            64            77       176            59
# 41           70            83            90       346            61
#
#     Sprint Speed  Agility  Reactions  Balance  Power  Shot Power  Jumping  \
# ID
# 2             74     68.0         69     68.0    347          74     68.0
# 16            50     62.0         65     72.0    324          75     54.0
# 27            42     71.0         59     75.0    284          72     58.0
# 36            62      NaN         55      NaN    239          63      NaN
# 41            56     79.0         75     75.0    297          67     40.0
#
#     Stamina  Strength  Long Shots  Mentality  Aggression  Interceptions  \
# ID
# 2        69        68          68        320          72           69.0
# 16       64        60          71        362          71           71.0
# 27       29        56          69        317          69           39.0
# 36       51        66          59        271          59           70.0
# 41       58        62          70        370          58           70.0
#
#     Positioning  Vision  Penalties  Composure  Defending  Marking  \
# ID
# 2          63.0    66.0         50        NaN        208       70
# 16         72.0    73.0         75       79.0        153       70
# 27         69.0    74.0         66        NaN         99       35
# 36         72.0     NaN         70        NaN         75       34
# 41         78.0    93.0         71       89.0        181       68
#
#     Standing Tackle  Sliding Tackle  Goalkeeping  GK Diving  GK Handling  \
# ID
# 2                69            69.0           56         14            5
# 16               43            40.0           56          9           12
# 27               34            30.0           51          9            6
# 36               41             NaN           68          5           21
# 41               57            56.0           45          6           13
#
#     GK Kicking  GK Positioning  GK Reflexes  Total Stats  Base Stats  W/F  SM  \
# ID
# 2           15              10           12         1929         408  3 ★  2★
# 16          13              11           11         1906         385  4 ★  3★
# 27          13              16            7         1770         354  4 ★  4★
# 36          64              21           21         1348         369  3 ★  1★
# 41           6              13            7         2014         420  4 ★  4★
#
#        A/W     D/W   IR  PAC  SHO  PAS  DRI  DEF  PHY Hits    LS    ST    RS  \
# ID
# 2   Medium    High  2 ★   71   59   70   71   68   69    4  65+0  65+0  65+0
# 16  Medium  Medium  1 ★   53   69   73   69   58   63    4  67+1  67+1  67+1
# 27  Medium     Low  2 ★   45   68   76   77   36   52   11  64+0  64+0  64+0
# 36     NaN     NaN  1 ★   61   66   66   69   47   60    3  67+0  67+0  67+0
# 41    High  Medium  4 ★   58   70   85   85   63   59  149  72+3  72+3  72+3
#
#       LW    LF    CF    RF    RW    LAM    CAM    RAM    LM   LCM    CM   RCM  \
# ID
# 2   68+0  67+0  67+0  67+0  68+0   68+0   68+0   68+0  69+0  69+0  69+0  69+0
# 16  67+0  68+0  68+0  68+0  67+0   70+1   70+1   70+1  68+1  70+1  70+1  70+1
# 27  70+0  69+0  69+0  69+0  70+0   71+0   71+0   71+0  68+0  66+0  66+0  66+0
# 36  66+0  67+0  67+0  67+0  66+0   70+0   70+0   70+0  66+0  68+0  68+0  68+0
# 41  79+0  79+0  79+0  79+0  79+0  82+-1  82+-1  82+-1  79+2  81+0  81+0  81+0
#
#       RM    LWB    LDM    CDM    RDM    RWB     LB   LCB    CB   RCB     RB  \
# ID
# 2   69+0  71+-2  70+-1  70+-1  70+-1  71+-2  70+-1  69+0  69+0  69+0  70+-1
# 16  68+1   62+1   66+1   66+1   66+1   62+1   60+1  60+1  60+1  60+1   60+1
# 27  68+0   52+0   54+0   54+0   54+0   52+0   47+0  46+0  46+0  46+0   47+0
# 36  66+0   56+0   65+0   65+0   65+0   56+0   57+0  51+0  51+0  51+0   57+0
# 41  79+2   70+3   73+3   73+3   73+3   70+3   67+3  64+3  64+3  64+3   67+3
#
#       GK
# ID
# 2   17+0
# 16  17+1
# 27  15+0
# 36  22+0
# 41  17+3

# %%
df = df_initial.copy()   #to store the initial df and use the sopy going forward

# %%
cols_count = df.shape[1]

# %%
df.shape
# Out:
# (17125, 96)

# %%
print(f'dataframe has {df.shape[0]} rows and {df.shape[1]} columns')
# Out:
# dataframe has 17125 rows and 96 columns

# %%
df.dtypes.to_frame().T # to see the data type of each column
# Out:
#      Age    OVA    BOV      BP    POT  Height  Weight    foot Growth  \
# 0  int64  int64  int64  object  int64  object  object  object  int64
#
#   Loan Date End   Value    Wage Release Clause Contract Attacking Crossing  \
# 0        object  object  object         object   object     int64    int64
#
#   Finishing Heading Accuracy Short Passing  Volleys  Skill Dribbling    Curve  \
# 0     int64            int64         int64  float64  int64     int64  float64
#
#   FK Accuracy Long Passing Ball Control Movement Acceleration Sprint Speed  \
# 0       int64        int64        int64    int64        int64        int64
#
#    Agility Reactions  Balance  Power Shot Power  Jumping Stamina Strength  \
# 0  float64     int64  float64  int64      int64  float64   int64    int64
#
#   Long Shots Mentality Aggression Interceptions Positioning   Vision  \
# 0      int64     int64      int64       float64     float64  float64
#
#   Penalties Composure Defending Marking Standing Tackle Sliding Tackle  \
# 0     int64   float64     int64   int64           int64        float64
#
#   Goalkeeping GK Diving GK Handling GK Kicking GK Positioning GK Reflexes  \
# 0       int64     int64       int64      int64          int64       int64
#
#   Total Stats Base Stats     W/F      SM     A/W     D/W      IR    PAC  \
# 0       int64      int64  object  object  object  object  object  int64
#
#      SHO    PAS    DRI    DEF    PHY    Hits      LS      ST      RS      LW  \
# 0  int64  int64  int64  int64  int64  object  object  object  object  object
#
#        LF      CF      RF      RW     LAM     CAM     RAM      LM     LCM  \
# 0  object  object  object  object  object  object  object  object  object
#
#        CM     RCM      RM     LWB     LDM     CDM     RDM     RWB      LB  \
# 0  object  object  object  object  object  object  object  object  object
#
#       LCB      CB     RCB      RB      GK
# 0  object  object  object  object  object

# %% [markdown]
# ### Cleaning the data

# %% [markdown]
# #### Standardising the header names

# %%
columns = []
for i in range (len(df.columns)):
    columns.append(df.columns[i].lower().replace(" ", "_"))
df.columns = columns #we replace the original column names with the standarized ones
df.head()            #justo check the column names
# Out:
#     age  ova  bov   bp  pot height  weight   foot  growth loan_date_end  \
# ID
# 2    33   69   71  LWB   69   6'0"  181lbs   Left       0           NaN
# 16   37   71   70   CM   71  5'10"  143lbs  Right       0           NaN
# 27   33   71   71  CAM   71   5'9"  161lbs  Right       0           NaN
# 36   36   68   70   ST   82  5'11"  165lbs  Right      14           NaN
# 41   36   81   82  CAM   81   5'7"  150lbs  Right       0           NaN
#
#     value  wage release_clause     contract  attacking  crossing  finishing  \
# ID
# 2   €625K   €7K             €0  2008 ~ 2016        313        75         50
# 16  €600K   €7K          €1.1M  2014 ~ 2019        337        68         64
# 27  €1.1M  €15K             €0  2016 ~ 2020        337        80         64
# 36     €0    €0             €0         2009        264        54         70
# 41  €5.5M  €12K          €7.2M  2018 ~ 2021        367        75         69
#
#     heading_accuracy  short_passing  volleys  skill  dribbling  curve  \
# ID
# 2                 59             71     58.0    338         73   65.0
# 16                61             76     68.0    369         69   79.0
# 27                41             77     75.0    387         79   84.0
# 36                60             80      NaN    255         68    NaN
# 41                54             90     79.0    408         85   80.0
#
#     fk_accuracy  long_passing  ball_control  movement  acceleration  \
# ID
# 2            60            69            71       347            68
# 16           79            71            71       305            56
# 27           77            69            78       295            48
# 36           46            64            77       176            59
# 41           70            83            90       346            61
#
#     sprint_speed  agility  reactions  balance  power  shot_power  jumping  \
# ID
# 2             74     68.0         69     68.0    347          74     68.0
# 16            50     62.0         65     72.0    324          75     54.0
# 27            42     71.0         59     75.0    284          72     58.0
# 36            62      NaN         55      NaN    239          63      NaN
# 41            56     79.0         75     75.0    297          67     40.0
#
#     stamina  strength  long_shots  mentality  aggression  interceptions  \
# ID
# 2        69        68          68        320          72           69.0
# 16       64        60          71        362          71           71.0
# 27       29        56          69        317          69           39.0
# 36       51        66          59        271          59           70.0
# 41       58        62          70        370          58           70.0
#
#     positioning  vision  penalties  composure  defending  marking  \
# ID
# 2          63.0    66.0         50        NaN        208       70
# 16         72.0    73.0         75       79.0        153       70
# 27         69.0    74.0         66        NaN         99       35
# 36         72.0     NaN         70        NaN         75       34
# 41         78.0    93.0         71       89.0        181       68
#
#     standing_tackle  sliding_tackle  goalkeeping  gk_diving  gk_handling  \
# ID
# 2                69            69.0           56         14            5
# 16               43            40.0           56          9           12
# 27               34            30.0           51          9            6
# 36               41             NaN           68          5           21
# 41               57            56.0           45          6           13
#
#     gk_kicking  gk_positioning  gk_reflexes  total_stats  base_stats  w/f  sm  \
# ID
# 2           15              10           12         1929         408  3 ★  2★
# 16          13              11           11         1906         385  4 ★  3★
# 27          13              16            7         1770         354  4 ★  4★
# 36          64              21           21         1348         369  3 ★  1★
# 41           6              13            7         2014         420  4 ★  4★
#
#        a/w     d/w   ir  pac  sho  pas  dri  def  phy hits    ls    st    rs  \
# ID
# 2   Medium    High  2 ★   71   59   70   71   68   69    4  65+0  65+0  65+0
# 16  Medium  Medium  1 ★   53   69   73   69   58   63    4  67+1  67+1  67+1
# 27  Medium     Low  2 ★   45   68   76   77   36   52   11  64+0  64+0  64+0
# 36     NaN     NaN  1 ★   61   66   66   69   47   60    3  67+0  67+0  67+0
# 41    High  Medium  4 ★   58   70   85   85   63   59  149  72+3  72+3  72+3
#
#       lw    lf    cf    rf    rw    lam    cam    ram    lm   lcm    cm   rcm  \
# ID
# 2   68+0  67+0  67+0  67+0  68+0   68+0   68+0   68+0  69+0  69+0  69+0  69+0
# 16  67+0  68+0  68+0  68+0  67+0   70+1   70+1   70+1  68+1  70+1  70+1  70+1
# 27  70+0  69+0  69+0  69+0  70+0   71+0   71+0   71+0  68+0  66+0  66+0  66+0
# 36  66+0  67+0  67+0  67+0  66+0   70+0   70+0   70+0  66+0  68+0  68+0  68+0
# 41  79+0  79+0  79+0  79+0  79+0  82+-1  82+-1  82+-1  79+2  81+0  81+0  81+0
#
#       rm    lwb    ldm    cdm    rdm    rwb     lb   lcb    cb   rcb     rb  \
# ID
# 2   69+0  71+-2  70+-1  70+-1  70+-1  71+-2  70+-1  69+0  69+0  69+0  70+-1
# 16  68+1   62+1   66+1   66+1   66+1   62+1   60+1  60+1  60+1  60+1   60+1
# 27  68+0   52+0   54+0   54+0   54+0   52+0   47+0  46+0  46+0  46+0   47+0
# 36  66+0   56+0   65+0   65+0   65+0   56+0   57+0  51+0  51+0  51+0   57+0
# 41  79+2   70+3   73+3   73+3   73+3   70+3   67+3  64+3  64+3  64+3   67+3
#
#       gk
# ID
# 2   17+0
# 16  17+1
# 27  15+0
# 36  22+0
# 41  17+3

# %% [markdown]
# ### a function that removes the '★' symbol

# %%
def clean_stars(text_with_star):
     return int(text_with_star.strip('★'))

# %%
for col in ['w/f','sm','ir']:
    df[col] = df[col].apply(clean_stars)

# %%
df[ ['w/f','sm','ir']].head()
# Out:
#     w/f  sm  ir
# ID
# 2     3   2   2
# 16    4   3   1
# 27    4   4   2
# 36    3   1   1
# 41    4   4   4

# %% [markdown]
# ### Clean the currencies

# %%
def clean_currency(value):
    if value[-1]=='K':
        return float(value[:-1])*1000
    elif value[-1]=='M':
        return float(value[:-1])*1000000
    else:
        return float(value)

# %%
# test function clean_currency
assert clean_currency('2K') == 2000

# %% [markdown]
# ### `wage`

# %%
# see which letters appear in wage
set(df['wage'].str[-1].to_list())
# Out:
# {'0', 'K'}

# %%
# verify that only euros are in this col
set(df['wage'].str[0].to_list())
# Out:
# {'€'}

# %%
df['wage'] = df['wage'].str.replace('€', '').apply(clean_currency)

# %% [markdown]
# ### `value`

# %%
# see which letters appear in value
set(df['value'].str[-1].to_list())
# Out:
# {'0', 'K', 'M'}

# %%
# verify that only euros are in this col
set(df['value'].str[0].to_list())
# Out:
# {'€'}

# %%
df['value'] = df['value'].str.replace('€', '').apply(clean_currency)

# %% [markdown]
# ### `release_clause`

# %%
# see which letters appear in release_clause
set(df['release_clause'].str[-1].to_list())
# Out:
# {'0', 'K', 'M'}

# %%
# verify that only euros are in this col
set(df['release_clause'].str[0].to_list())
# Out:
# {'€'}

# %%
df['release_clause'] = df['release_clause'].str.replace('€', '').apply(clean_currency)

# %% [markdown]
# **Fancy way**

# %%
# currency_cols = ['wage', 'value', 'release_clause']

# for col in currency_cols:
#      df[f'{col}_clean'] = df[col].str.replace('€', '').apply(clean_currency)

# %%
#df.head()[currency_cols]

# %%
df.shape
# Out:
# (17125, 96)

# %% [markdown]
# ### REMOVING PLUS MINUS

# %%
# Verify that there is no -+: If True that means that the assumption that -+ never appears is true
footbal_stat_cols = df.columns[69:96]

for col in footbal_stat_cols:
    print(f'{col}:', abs(df[col].str.find('-+').sum())==df.shape[0])
# Out:
# ls: True
# st: True
# rs: True
# lw: True
# lf: True
# cf: True
# rf: True
# rw: True
# lam: True
# cam: True
# ram: True
# lm: True
# lcm: True
# cm: True
# rcm: True
# rm: True
# lwb: True
# ldm: True
# cdm: True
# rdm: True
# rwb: True
# lb: True
# lcb: True
# cb: True
# rcb: True
# rb: True
# gk: True

# %%
test =  'dar+b'
ind = test.index('+')
print(ind)

test[:ind]

#written just to test how to find the location of a plus sign
# Out:
# 3
# 'dar'

# %%
def clean_footbal_stats(football_stat):
    """Cleaning the +s and -s"""
    ind = football_stat.index('+')
    return int(football_stat[:ind])

# %%
test = '65+0'

ind = test.index('+')


test[:2]
# Out:
# '65'

# %%
clean_footbal_stats(test)
# Out:
# 65

# %%
df.shape
# Out:
# (17125, 96)

# %%
footbal_stat_cols = df.columns[70:96]

for col in footbal_stat_cols:
    df[col] = df[col].apply(clean_footbal_stats)

# %%
df.head()
# Out:
#     age  ova  bov   bp  pot height  weight   foot  growth loan_date_end  \
# ID
# 2    33   69   71  LWB   69   6'0"  181lbs   Left       0           NaN
# 16   37   71   70   CM   71  5'10"  143lbs  Right       0           NaN
# 27   33   71   71  CAM   71   5'9"  161lbs  Right       0           NaN
# 36   36   68   70   ST   82  5'11"  165lbs  Right      14           NaN
# 41   36   81   82  CAM   81   5'7"  150lbs  Right       0           NaN
#
#         value     wage  release_clause     contract  attacking  crossing  \
# ID
# 2    625000.0   7000.0             0.0  2008 ~ 2016        313        75
# 16   600000.0   7000.0       1100000.0  2014 ~ 2019        337        68
# 27  1100000.0  15000.0             0.0  2016 ~ 2020        337        80
# 36        0.0      0.0             0.0         2009        264        54
# 41  5500000.0  12000.0       7200000.0  2018 ~ 2021        367        75
#
#     finishing  heading_accuracy  short_passing  volleys  skill  dribbling  \
# ID
# 2          50                59             71     58.0    338         73
# 16         64                61             76     68.0    369         69
# 27         64                41             77     75.0    387         79
# 36         70                60             80      NaN    255         68
# 41         69                54             90     79.0    408         85
#
#     curve  fk_accuracy  long_passing  ball_control  movement  acceleration  \
# ID
# 2    65.0           60            69            71       347            68
# 16   79.0           79            71            71       305            56
# 27   84.0           77            69            78       295            48
# 36    NaN           46            64            77       176            59
# 41   80.0           70            83            90       346            61
#
#     sprint_speed  agility  reactions  balance  power  shot_power  jumping  \
# ID
# 2             74     68.0         69     68.0    347          74     68.0
# 16            50     62.0         65     72.0    324          75     54.0
# 27            42     71.0         59     75.0    284          72     58.0
# 36            62      NaN         55      NaN    239          63      NaN
# 41            56     79.0         75     75.0    297          67     40.0
#
#     stamina  strength  long_shots  mentality  aggression  interceptions  \
# ID
# 2        69        68          68        320          72           69.0
# 16       64        60          71        362          71           71.0
# 27       29        56          69        317          69           39.0
# 36       51        66          59        271          59           70.0
# 41       58        62          70        370          58           70.0
#
#     positioning  vision  penalties  composure  defending  marking  \
# ID
# 2          63.0    66.0         50        NaN        208       70
# 16         72.0    73.0         75       79.0        153       70
# 27         69.0    74.0         66        NaN         99       35
# 36         72.0     NaN         70        NaN         75       34
# 41         78.0    93.0         71       89.0        181       68
#
#     standing_tackle  sliding_tackle  goalkeeping  gk_diving  gk_handling  \
# ID
# 2                69            69.0           56         14            5
# 16               43            40.0           56          9           12
# 27               34            30.0           51          9            6
# 36               41             NaN           68          5           21
# 41               57            56.0           45          6           13
#
#     gk_kicking  gk_positioning  gk_reflexes  total_stats  base_stats  w/f  sm  \
# ID
# 2           15              10           12         1929         408    3   2
# 16          13              11           11         1906         385    4   3
# 27          13              16            7         1770         354    4   4
# 36          64              21           21         1348         369    3   1
# 41           6              13            7         2014         420    4   4
#
#        a/w     d/w  ir  pac  sho  pas  dri  def  phy hits    ls  st  rs  lw  \
# ID
# 2   Medium    High   2   71   59   70   71   68   69    4  65+0  65  65  68
# 16  Medium  Medium   1   53   69   73   69   58   63    4  67+1  67  67  67
# 27  Medium     Low   2   45   68   76   77   36   52   11  64+0  64  64  70
# 36     NaN     NaN   1   61   66   66   69   47   60    3  67+0  67  67  66
# 41    High  Medium   4   58   70   85   85   63   59  149  72+3  72  72  79
#
#     lf  cf  rf  rw  lam  cam  ram  lm  lcm  cm  rcm  rm  lwb  ldm  cdm  rdm  \
# ID
# 2   67  67  67  68   68   68   68  69   69  69   69  69   71   70   70   70
# 16  68  68  68  67   70   70   70  68   70  70   70  68   62   66   66   66
# 27  69  69  69  70   71   71   71  68   66  66   66  68   52   54   54   54
# 36  67  67  67  66   70   70   70  66   68  68   68  66   56   65   65   65
# 41  79  79  79  79   82   82   82  79   81  81   81  79   70   73   73   73
#
#     rwb  lb  lcb  cb  rcb  rb  gk
# ID
# 2    71  70   69  69   69  70  17
# 16   62  60   60  60   60  60  17
# 27   52  47   46  46   46  47  15
# 36   56  57   51  51   51  57  22
# 41   70  67   64  64   64  67  17

# %% [markdown]
# #### Dividing the dataframe into categorical and numerical sub-datasets

# %%
numeric = df.select_dtypes(include=np.number)
numeric.head()
# Out:
#     age  ova  bov  pot  growth      value     wage  release_clause  attacking  \
# ID
# 2    33   69   71   69       0   625000.0   7000.0             0.0        313
# 16   37   71   70   71       0   600000.0   7000.0       1100000.0        337
# 27   33   71   71   71       0  1100000.0  15000.0             0.0        337
# 36   36   68   70   82      14        0.0      0.0             0.0        264
# 41   36   81   82   81       0  5500000.0  12000.0       7200000.0        367
#
#     crossing  finishing  heading_accuracy  short_passing  volleys  skill  \
# ID
# 2         75         50                59             71     58.0    338
# 16        68         64                61             76     68.0    369
# 27        80         64                41             77     75.0    387
# 36        54         70                60             80      NaN    255
# 41        75         69                54             90     79.0    408
#
#     dribbling  curve  fk_accuracy  long_passing  ball_control  movement  \
# ID
# 2          73   65.0           60            69            71       347
# 16         69   79.0           79            71            71       305
# 27         79   84.0           77            69            78       295
# 36         68    NaN           46            64            77       176
# 41         85   80.0           70            83            90       346
#
#     acceleration  sprint_speed  agility  reactions  balance  power  \
# ID
# 2             68            74     68.0         69     68.0    347
# 16            56            50     62.0         65     72.0    324
# 27            48            42     71.0         59     75.0    284
# 36            59            62      NaN         55      NaN    239
# 41            61            56     79.0         75     75.0    297
#
#     shot_power  jumping  stamina  strength  long_shots  mentality  aggression  \
# ID
# 2           74     68.0       69        68          68        320          72
# 16          75     54.0       64        60          71        362          71
# 27          72     58.0       29        56          69        317          69
# 36          63      NaN       51        66          59        271          59
# 41          67     40.0       58        62          70        370          58
#
#     interceptions  positioning  vision  penalties  composure  defending  \
# ID
# 2            69.0         63.0    66.0         50        NaN        208
# 16           71.0         72.0    73.0         75       79.0        153
# 27           39.0         69.0    74.0         66        NaN         99
# 36           70.0         72.0     NaN         70        NaN         75
# 41           70.0         78.0    93.0         71       89.0        181
#
#     marking  standing_tackle  sliding_tackle  goalkeeping  gk_diving  \
# ID
# 2        70               69            69.0           56         14
# 16       70               43            40.0           56          9
# 27       35               34            30.0           51          9
# 36       34               41             NaN           68          5
# 41       68               57            56.0           45          6
#
#     gk_handling  gk_kicking  gk_positioning  gk_reflexes  total_stats  \
# ID
# 2             5          15              10           12         1929
# 16           12          13              11           11         1906
# 27            6          13              16            7         1770
# 36           21          64              21           21         1348
# 41           13           6              13            7         2014
#
#     base_stats  w/f  sm  ir  pac  sho  pas  dri  def  phy  st  rs  lw  lf  cf  \
# ID
# 2          408    3   2   2   71   59   70   71   68   69  65  65  68  67  67
# 16         385    4   3   1   53   69   73   69   58   63  67  67  67  68  68
# 27         354    4   4   2   45   68   76   77   36   52  64  64  70  69  69
# 36         369    3   1   1   61   66   66   69   47   60  67  67  66  67  67
# 41         420    4   4   4   58   70   85   85   63   59  72  72  79  79  79
#
#     rf  rw  lam  cam  ram  lm  lcm  cm  rcm  rm  lwb  ldm  cdm  rdm  rwb  lb  \
# ID
# 2   67  68   68   68   68  69   69  69   69  69   71   70   70   70   71  70
# 16  68  67   70   70   70  68   70  70   70  68   62   66   66   66   62  60
# 27  69  70   71   71   71  68   66  66   66  68   52   54   54   54   52  47
# 36  67  66   70   70   70  66   68  68   68  66   56   65   65   65   56  57
# 41  79  79   82   82   82  79   81  81   81  79   70   73   73   73   70  67
#
#     lcb  cb  rcb  rb  gk
# ID
# 2    69  69   69  70  17
# 16   60  60   60  60  17
# 27   46  46   46  47  15
# 36   51  51   51  57  22
# 41   64  64   64  67  17

# %%
numeric.head()
# Out:
#     age  ova  bov  pot  growth      value     wage  release_clause  attacking  \
# ID
# 2    33   69   71   69       0   625000.0   7000.0             0.0        313
# 16   37   71   70   71       0   600000.0   7000.0       1100000.0        337
# 27   33   71   71   71       0  1100000.0  15000.0             0.0        337
# 36   36   68   70   82      14        0.0      0.0             0.0        264
# 41   36   81   82   81       0  5500000.0  12000.0       7200000.0        367
#
#     crossing  finishing  heading_accuracy  short_passing  volleys  skill  \
# ID
# 2         75         50                59             71     58.0    338
# 16        68         64                61             76     68.0    369
# 27        80         64                41             77     75.0    387
# 36        54         70                60             80      NaN    255
# 41        75         69                54             90     79.0    408
#
#     dribbling  curve  fk_accuracy  long_passing  ball_control  movement  \
# ID
# 2          73   65.0           60            69            71       347
# 16         69   79.0           79            71            71       305
# 27         79   84.0           77            69            78       295
# 36         68    NaN           46            64            77       176
# 41         85   80.0           70            83            90       346
#
#     acceleration  sprint_speed  agility  reactions  balance  power  \
# ID
# 2             68            74     68.0         69     68.0    347
# 16            56            50     62.0         65     72.0    324
# 27            48            42     71.0         59     75.0    284
# 36            59            62      NaN         55      NaN    239
# 41            61            56     79.0         75     75.0    297
#
#     shot_power  jumping  stamina  strength  long_shots  mentality  aggression  \
# ID
# 2           74     68.0       69        68          68        320          72
# 16          75     54.0       64        60          71        362          71
# 27          72     58.0       29        56          69        317          69
# 36          63      NaN       51        66          59        271          59
# 41          67     40.0       58        62          70        370          58
#
#     interceptions  positioning  vision  penalties  composure  defending  \
# ID
# 2            69.0         63.0    66.0         50        NaN        208
# 16           71.0         72.0    73.0         75       79.0        153
# 27           39.0         69.0    74.0         66        NaN         99
# 36           70.0         72.0     NaN         70        NaN         75
# 41           70.0         78.0    93.0         71       89.0        181
#
#     marking  standing_tackle  sliding_tackle  goalkeeping  gk_diving  \
# ID
# 2        70               69            69.0           56         14
# 16       70               43            40.0           56          9
# 27       35               34            30.0           51          9
# 36       34               41             NaN           68          5
# 41       68               57            56.0           45          6
#
#     gk_handling  gk_kicking  gk_positioning  gk_reflexes  total_stats  \
# ID
# 2             5          15              10           12         1929
# 16           12          13              11           11         1906
# 27            6          13              16            7         1770
# 36           21          64              21           21         1348
# 41           13           6              13            7         2014
#
#     base_stats  w/f  sm  ir  pac  sho  pas  dri  def  phy  st  rs  lw  lf  cf  \
# ID
# 2          408    3   2   2   71   59   70   71   68   69  65  65  68  67  67
# 16         385    4   3   1   53   69   73   69   58   63  67  67  67  68  68
# 27         354    4   4   2   45   68   76   77   36   52  64  64  70  69  69
# 36         369    3   1   1   61   66   66   69   47   60  67  67  66  67  67
# 41         420    4   4   4   58   70   85   85   63   59  72  72  79  79  79
#
#     rf  rw  lam  cam  ram  lm  lcm  cm  rcm  rm  lwb  ldm  cdm  rdm  rwb  lb  \
# ID
# 2   67  68   68   68   68  69   69  69   69  69   71   70   70   70   71  70
# 16  68  67   70   70   70  68   70  70   70  68   62   66   66   66   62  60
# 27  69  70   71   71   71  68   66  66   66  68   52   54   54   54   52  47
# 36  67  66   70   70   70  66   68  68   68  66   56   65   65   65   56  57
# 41  79  79   82   82   82  79   81  81   81  79   70   73   73   73   70  67
#
#     lcb  cb  rcb  rb  gk
# ID
# 2    69  69   69  70  17
# 16   60  60   60  60  17
# 27   46  46   46  47  15
# 36   51  51   51  57  22
# 41   64  64   64  67  17

# %%
categorical = df.select_dtypes(include = ['object'])
categorical.head()
# Out:
#      bp height  weight   foot loan_date_end     contract     a/w     d/w hits  \
# ID
# 2   LWB   6'0"  181lbs   Left           NaN  2008 ~ 2016  Medium    High    4
# 16   CM  5'10"  143lbs  Right           NaN  2014 ~ 2019  Medium  Medium    4
# 27  CAM   5'9"  161lbs  Right           NaN  2016 ~ 2020  Medium     Low   11
# 36   ST  5'11"  165lbs  Right           NaN         2009     NaN     NaN    3
# 41  CAM   5'7"  150lbs  Right           NaN  2018 ~ 2021    High  Medium  149
#
#       ls
# ID
# 2   65+0
# 16  67+1
# 27  64+0
# 36  67+0
# 41  72+3

# %%
print(f'There are {len(numeric.columns)} numeric columns and {len(categorical.columns)} categorical columns')
# Out:
# There are 86 numeric columns and 10 categorical columns

# %%
print(f'The numerical columns are {numeric.columns.tolist()}')
# Out:
# The numerical columns are ['age', 'ova', 'bov', 'pot', 'growth', 'value', 'wage', 'release_clause', 'attacking', 'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys', 'skill', 'dribbling', 'curve', 'fk_accuracy', 'long_passing', 'ball_control', 'movement', 'acceleration', 'sprint_speed', 'agility', 'reactions', 'balance', 'power', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'mentality', 'aggression', 'interceptions', 'positioning', 'vision', 'penalties', 'composure', 'defending', 'marking', 'standing_tackle', 'sliding_tackle', 'goalkeeping', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes', 'total_stats', 'base_stats', 'w/f', 'sm', 'ir', 'pac', 'sho', 'pas', 'dri', 'def', 'phy', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb', 'gk']

# %%
print(f'The categorical columns are {categorical.columns.tolist()}')
# Out:
# The categorical columns are ['bp', 'height', 'weight', 'foot', 'loan_date_end', 'contract', 'a/w', 'd/w', 'hits', 'ls']

# %% [markdown]
# #### Changing the data type of columns from float to integer

# %%
ph_attributes = df.select_dtypes(include=['float'])
ph_attributes = ph_attributes.drop(['value', 'wage', 'release_clause'], axis=True)
ph_attributes.head()
# Out:
#     volleys  curve  agility  balance  jumping  interceptions  positioning  \
# ID
# 2      58.0   65.0     68.0     68.0     68.0           69.0         63.0
# 16     68.0   79.0     62.0     72.0     54.0           71.0         72.0
# 27     75.0   84.0     71.0     75.0     58.0           39.0         69.0
# 36      NaN    NaN      NaN      NaN      NaN           70.0         72.0
# 41     79.0   80.0     79.0     75.0     40.0           70.0         78.0
#
#     vision  composure  sliding_tackle
# ID
# 2     66.0        NaN            69.0
# 16    73.0       79.0            40.0
# 27    74.0        NaN            30.0
# 36     NaN        NaN             NaN
# 41    93.0       89.0            56.0

# %%
ph_attributes.isna().sum()
# Out:
# volleys            58
# curve              58
# agility            58
# balance            58
# jumping            58
# interceptions       7
# positioning         7
# vision             58
# composure         423
# sliding_tackle     58
# dtype: int64

# %%
ph_attributes = ph_attributes[ph_attributes['composure'].notna()]
ph_attributes.isna().sum()
# Out:
# volleys           0
# curve             0
# agility           0
# balance           0
# jumping           0
# interceptions     0
# positioning       0
# vision            0
# composure         0
# sliding_tackle    0
# dtype: int64

# %%
ph_attributes = ph_attributes.drop_duplicates()
ph_attributes.shape
# Out:
# (17105, 10)

# %%
ph_attributes.isna().sum()
# Out:
# volleys            51
# curve              51
# agility            51
# balance            51
# jumping            51
# interceptions       1
# positioning         1
# vision             51
# composure         416
# sliding_tackle     51
# dtype: int64

# %%
round(ph_attributes.isna().sum()/len(ph_attributes),4)*100
# Out:
# volleys           0.30
# curve             0.30
# agility           0.30
# balance           0.30
# jumping           0.30
# interceptions     0.01
# positioning       0.01
# vision            0.30
# composure         2.43
# sliding_tackle    0.30
# dtype: float64

# %%
ph_attributes = ph_attributes.astype('int')

# %%
ph_attributes.head()
# Out:
#       volleys  curve  agility  balance  jumping  interceptions  positioning  \
# ID
# 16         68     79       62       72       54             71           72
# 41         79     80       79       75       40             70           78
# 80         69     83       67       81       72             62           65
# 330        84     82       77       83       62             34           85
# 1179       17     20       55       49       71             28           12
#
#       vision  composure  sliding_tackle
# ID
# 16        73         79              40
# 41        93         89              56
# 80        85         80              60
# 330       82         86              17
# 1179      50         70              11

# %%
df.select_dtypes(include=['float']).columns.tolist()

# %%
df_copy = df.copy()

# %% [markdown]
# #### Dropping the unneccessary columns

# %% [markdown]
# #### Dropping the duplicate columns

# %% [markdown]
# #### Dealing with NaN values

# %% [markdown]
# #### Dealing with Outliers

# %% [markdown]
# #### Regression model
